# %%
import pandas as pd

# %%
df = pd.read_excel("Complaints Data Sample.xlsb", engine='pyxlsb')

# %%
df
# Out:
#       Violation Number  Type  Violation discovery date  \
# 0                  125  جودة              43210.886990
# 1                  137  جودة              43212.411059
# 2                  145  جودة              43212.566062
# 3                  153  جودة              43212.590655
# 4                  162  جودة              43212.606517
# ...                ...   ...                       ...
# 4152           1405523  جودة              44094.606138
# 4153           1405552  جودة              44095.620740
# 4154           1405562  جودة              44095.902394
# 4155           1405649  جودة              44099.655950
# 4156           1405656  جودة              44100.436348
#
#                                   Violation description  \
# 0           اختيار نوع – أو تصنيف – أو مسار خاطئ للخلاف
# 1     الادلاء بمعلومات غير صحيحة أو غير مكتملة للعمي...
# 2                                         عدم خدمة عميل
# 3           اختيار نوع – أو تصنيف – أو مسار خاطئ للخلاف
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4157 entries, 0 to 4156
# Data columns (total 33 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Violation Number                 4157 non-null   int64
#  1   Type                             4157 non-null   object
#  2   Violation discovery date         4157 non-null   float64
#  3   Violation description            4157 non-null   object
#  4   Violation details                4135 non-null   object
#  5   Violation number on CCC portal   1171 non-null   object
#  6   Assigned date to CCC             1917 non-null   float64
#  7   Deduction amount                 1088 non-null   object
#  8   Violation date                   4157 non-null   int64
#  9   Violation number                 1919 non-null   object
#  10  Customer number                  4157 non-null   int64
#  11  Agent HR ID                      4157 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Violation Number', 'Type', 'Violation discovery date',
#        'Violation description', 'Violation details',
#        'Violation number on CCC portal', 'Assigned date to CCC',
#        'Deduction amount', 'Violation date', 'Violation number',
#        'Customer number', 'Agent HR ID', 'Agent name', 'Company name',
#        'STC user ID', 'STC direct manger', 'STC direct manger status',
#        'STC direct manger comment', 'CCC User ID', 'CCC status', 'CCC comment',
#        'Violation assigned date ', 'violation time closer ',
#        'CCC direct manger user ID', 'CCC direct manger status',
#        'CCC direct manger comment ', 'Violation assigned time ',
#        'violation time closer .1', 'Company', 'Status',
#        'Quality insurance comment (STC)', 'Final status', 'Process'],
#       dtype='object')

# %%
df['Violation number'].value_counts()
# Out:
# 1                  245
# 0                   83
# 5                   23
# 1-1167328687010      4
# 1-1277106001615      3
#                   ...
# 1-749272502931       1
# 14789654             1
# 1-1057910477588      1
# 1-759553358196       1
# 9                    1
# Name: Violation number, Length: 1466, dtype: int64
